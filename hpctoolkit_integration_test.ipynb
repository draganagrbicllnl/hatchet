# %%
from hatchet import GraphFrame

DATA_DIR = "/g/g91/grbic1/hpc-analysis/test_cases/gamess-1n-siCap-gpu.d/"
#DATA_DIR = "/g/g91/grbic1/hpc-analysis/test_cases/hpctoolkit-gamess-5n-manualbalance.d/"
#DATA_DIR = "/g/g91/grbic1/hpc-analysis/test_cases/hpctoolkit-gem-cpu.d/"

graphframe = GraphFrame.from_hpctoolkit_latest(DATA_DIR)
graphframe = GraphFrame.from_hpctoolkit_latest(DATA_DIR, max_depth=10)
graphframe = GraphFrame.from_hpctoolkit_latest(DATA_DIR, min_percentage_of_application_time=1)
graphframe = GraphFrame.from_hpctoolkit_latest(DATA_DIR, min_percentage_of_parent_time=1)

print(graphframe.tree())

#graphframe = graphframe.filter_out_nodes(min_percentage_of_application_time=1)
#graphframe = graphframe.filter_out_nodes(min_percentage_of_parent_time=1)
#graphframe = graphframe.filter_out_nodes(max_depth=10)
#graphframe.collapsable_visualization()
# Out:
# DATA IMPORTED
#     __          __       __         __
#    / /_  ____ _/ /______/ /_  ___  / /_
#   / __ \/ __ `/ __/ ___/ __ \/ _ \/ __/
#  / / / / /_/ / /_/ /__/ / / /  __/ /_
# /_/ /_/\__,_/\__/\___/_/ /_/\___/\__/  v2024.1.1
#
# 1608.492 entry
# └─ 1608.492 function: gamess_
#    └─ 1608.492 line: [gamess.00.x]:0
#       ├─ 3.177 function: trunc_
#       │  └─ 3.177 line: [gamess.00.x]:0
#       │     └─ 3.177 function: trncin_
#       │        └─ 3.177 line: [gamess.00.x]:0
#       │           └─ 3.177 function: nameio_
#       │              └─ 3.177 loop: [gamess.00.x]:0
#       │                 └─ 3.177 line: [gamess.00.x]:0
#       │                    └─ 3.177 function: Comm_bcast
#       │                       └─ 3.177 loop: [gamess.00.x]:0
#       │                          └─ 3.177 line: [gamess.00.x]:0
#       │                             └─ 3.177 function: MPI_Bcast
#       │                                └─ 3.177 line: [libmpi_cray.so.12.0.0]:0
# ...

# %%
print(graphframe.dataframe[["realtime (i)"]])
graphframe2 = graphframe + graphframe
print("OPERATION PERFORMED")
#print(graphframe2.tree())
print(graphframe.dataframe[["realtime (i)"]])
# Out:
#                                                     realtime (i)
# node
# {'depth': '0', 'id': '1195', 'name': '1', 'type...   1608.492466
# {'depth': '1', 'id': '1197', 'name': 'gamess_',...   1608.492466
# {'depth': '2', 'id': '1202', 'name': '[gamess.0...   1608.492466
# {'depth': '3', 'id': '18030', 'name': 'beging_'...    803.288660
# {'depth': '4', 'id': '18059', 'name': '[gamess....    803.288660
# ...                                                          ...
# {'depth': '44', 'id': '2965', 'name': '[libmpi_...    159.843866
# {'depth': '45', 'id': '2964', 'name': '[libmpi_...    159.843866
# {'depth': '46', 'id': '2951', 'name': '[libmpi_...    159.793802
# {'depth': '47', 'id': '2856', 'name': '__GI___s...    159.238081
# {'depth': '48', 'id': '251', 'name': '[libc-2.3...    159.238081
#
# [164 rows x 1 columns]
# OPERATION PERFORMED
#                                                     realtime (i)
# node
# ...
